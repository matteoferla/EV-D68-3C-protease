# %%
import requests
import pandas as pd
import operator

csets = pd.DataFrame( requests.get('https://fragalysis.diamond.ac.uk/api/compound-sets/').json()['results'] )
targets = pd.DataFrame( requests.get('https://fragalysis.diamond.ac.uk/api/targets/').json()['results'] )
id2name = targets.set_index('id').title.to_dict()
csets['target_name'] = csets.target.map(id2name)
csets['sdf_name'] = csets.submitted_sdf.apply(os.path.split).apply(operator.itemgetter(-1))

# %% [markdown]
# ## Download....

# %%
from rdkit import Chem
from pathlib import Path

def retrieve(sdf_url):
    name = Path(sdf_url).parts[-1]
    if Path(name).exists():
        return name
    with open(name, 'w') as fh:
        response: requests.Response = requests.get(sdf_url)
        response.raise_for_status()
        fh.write( response.text )
    return name

hits = []
dataset_info = {}
filenames: pd.Series = csets.loc[csets.target_name == 'D68EV3CPROA'].submitted_sdf.apply(retrieve)
filename: str
for filename in filenames.to_list():
    name = filename.split('.')[0]
    with Chem.SDMolSupplier(filename) as sdfh:
        header = next(sdfh)
        dataset_info[name] = header.GetPropsAsDict()
        for vc in sdfh:
            hits.SetProp('dataset', name)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[109], line 16
#      14 hits = []
#      15 dataset_info = {}
# ---> 16 filenames: pd.Series = csets.loc[csets.target_name == 'D68EV3CPROA'].submitted_sdf.apply(retrieve)
#      17 filename: str
#      18 for filename in filenames.to_list():
#
# File ~/.conda/envs/py310/lib/python3.10/site-packages/pandas/core/series.py:4630, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4520 def apply(
#    4521     self,
#    4522     func: AggFuncType,
#    (...)
#    4525     **kwargs,
#    4526 ) -> DataFrame | Series:
#    4527     """
#    4528     Invoke function on values of Series.
#    4529
#    (...)
#    4628     dtype: float64
#    4629     """
# -> 4630     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/.conda/envs/py310/lib/python3.10/site-packages/pandas/core/apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File ~/.conda/envs/py310/lib/python3.10/site-packages/pandas/core/apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/.conda/envs/py310/lib/python3.10/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[109], line 10, in retrieve(sdf_url)
#       8 with open(name, 'w') as fh:
#       9     response: requests.Response = requests.get(sdf_url)
# ---> 10     response.raise_for_status()
#      11     fh.write( response.text )
#      12 return name
#
# File ~/.conda/envs/py310/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://fragalysis.diamond.ac.uk/media/code/media/compound_sets/compound-set_fragnetv1_sujHlIc.sdf

# %% [markdown]
# ## Convert

# %%
from typing import Dict
import yaml

fragalysis2postera_yaml = \
'''
ref_url: design_submission_source_link
submitter_email: designer_email
# made up
submitter_name: designer_name
submitter_institution: designer_institution
generation_date: design_date
method: design_notes
# not matched to Fragalysis header
# related_molecules
'''

# made up: for each hit
# design_reference_hits: ref_mols
# design_rationale Computational follow-ups as part of Project 2.

fragalysis2postera: Dict[str, str] = yaml.load(fragalysis2postera_yaml, Loader=yaml.FullLoader)

# %%
# placeholder until download is fixed
filename = 'Fragmenstein-Tris.sdf'

from rdkit import Chem
from rdkit.Chem import AllChem

with Chem.SDMolSupplier(filename) as sdfh:
    header = next(sdfh)
    vcs = list(sdfh)[1:]
    
import re
for vc in vcs:
    ref_mols = ','.join(re.findall(r'(x\w+_\w\w)',  vc.GetProp('ref_mols') ))
    vc.SetProp('ref_mols', ref_mols)
        
#header_info = header.GetPropsAsDict()

def get_catalogue(name):
    if 'Z' in name:
        return name.split('-')[0]
    elif 'PV' in name:
        return 'PV-' + name.split('-')[1]
    else:
        raise ValueError


submissions = pd.DataFrame([{'Catalog ID': get_catalogue(vc.GetProp('_Name')),
                             'original_SMILES': Chem.MolToSmiles( AllChem.RemoveAllHs(vc)),
                             'design_reference_hits_XChem': vc.GetProp('ref_mols')
                            } for vc in vcs
                           ])

for col_fragalysis, col_post in fragalysis2postera.items():
    submissions[col_post] = header.GetProp(col_fragalysis)

# %%
import re
# get reference hits

with Chem.SDMolSupplier('D68EV3CPROA.filtered.sdf') as sdfh:
    hits = list(sdfh)
    
with Chem.SDMolSupplier('D68_new.sdf') as sdfh:
    hits.extend( list(sdfh) )
    
with Chem.SDMolSupplier('hits.sdf') as sdfh:
    hits.extend( list(sdfh) )
    
hitname2smiles = {h.GetProp('_Name'): Chem.MolToSmiles( AllChem.RemoveAllHs(h)) for h in hits}
hitname2smiles.update( {h.split('_')[0]: s for h, s in hitname2smiles.items()} )

def get_smiles(hit_name):
    """
    This would need to be custom...
    """
    if hit_name in hitname2smiles:
        return hitname2smiles[hit_name]
    simple = hit_name.split('_')[0]
    if simple in hitname2smiles:
        return hitname2smiles[simple]
    else:
        return '*'

# %%
submissions['designer_institution'] = 'University of Oxford'
submissions['design_rationale'] = 'Computational follow-ups as part of Project 2.'
ref_hits = submissions.design_reference_hits_XChem.apply(lambda s: s.split(','))
submissions['design_reference_hits_SMILES'] = ['.'.join([get_smiles(h) for h in hits]) for hits in ref_hits]

submissions.to_csv('test_set.csv')
submissions
# Out:
#           Catalog ID                                    original_SMILES  \
# 0         Z814868448                          Cc1cc(C(=O)NCC(C)(C)C)no1
# 1    PV-004271221850  COC(=O)Nc1cccc(C(=O)NC2CCN(C(=O)CCC(C)(C)C)CC2)c1
# 2    PV-005890491569  CC(=O)Nc1cc(C(=O)NC2CCN(C(=O)CCC(C)(C)F)CC2)ccc1F
# 3        Z1763400558                            CC(=O)NNC(=O)c1coc(C)c1
# 4    PV-001573842640      CC(=O)NC[C@H](NC(=O)Cc1ccc(=O)[nH]c1)C1CCCCC1
# ..               ...                                                ...
# 158      Z2170211741                  Cc1cc(NC(=O)CN[C@]2(C)CCOC2=O)no1
# 159      Z1211401012                  CC(=O)c1ccc(OCc2ccc3c(c2)CCC3)cc1
# 160      Z3777535315          CN1C(=O)CC[C@@H]1CNC(=O)NCc1ccc2c(c1)CCO2
# 161      Z1260734436                      CCc1ccc(CC(=O)NCCc2cccnc2)cc1
# 162      Z1885074939                     CC[C@@](C)(O)CNC(=O)c1cc(C)sn1
#
#     design_reference_hits_XChem  \
# 0             x1071_0A,x1052_1A
# 1             x1071_0A,x1020_0A
# 2             x1071_0A,x1020_0A
# 3             x1071_0A,x1052_1A
# 4             x1071_0A,x1498_0A
# ..                          ...
# 158           x2149_0A,x1052_1A
# 159           x0771_1A,x1140_0A
# 160           x2149_0A,x1140_0A
# 161           x1084_0A,x0980_0B
# 162           x1071_0A,x1052_1A
#
#                          design_submission_source_link  \
# 0    https://github.com/matteoferla/Fragment-hit-fo...
# 1    https://github.com/matteoferla/Fragment-hit-fo...
# 2    https://github.com/matteoferla/Fragment-hit-fo...
# 3    https://github.com/matteoferla/Fragment-hit-fo...
# 4    https://github.com/matteoferla/Fragment-hit-fo...
# ..                                                 ...
# 158  https://github.com/matteoferla/Fragment-hit-fo...
# 159  https://github.com/matteoferla/Fragment-hit-fo...
# 160  https://github.com/matteoferla/Fragment-hit-fo...
# 161  https://github.com/matteoferla/Fragment-hit-fo...
# 162  https://github.com/matteoferla/Fragment-hit-fo...
#
#                   designer_email designer_name  designer_institution  \
# 0    matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 1    matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 2    matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 3    matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 4    matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# ..                           ...           ...                   ...
# 158  matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 159  matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 160  matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 161  matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
# 162  matteo.ferla@stats.ox.ac.uk  Matteo Ferla  University of Oxford
#
#     design_date       design_notes  \
# 0    2023-09-05  Fragmenstein-Tris
# 1    2023-09-05  Fragmenstein-Tris
# 2    2023-09-05  Fragmenstein-Tris
# 3    2023-09-05  Fragmenstein-Tris
# 4    2023-09-05  Fragmenstein-Tris
# ..          ...                ...
# 158  2023-09-05  Fragmenstein-Tris
# 159  2023-09-05  Fragmenstein-Tris
# 160  2023-09-05  Fragmenstein-Tris
# 161  2023-09-05  Fragmenstein-Tris
# 162  2023-09-05  Fragmenstein-Tris
#
#                                    design_rationale  \
# 0    Computational follow-ups as part of Project 2.
# 1    Computational follow-ups as part of Project 2.
# 2    Computational follow-ups as part of Project 2.
# 3    Computational follow-ups as part of Project 2.
# 4    Computational follow-ups as part of Project 2.
# ..                                              ...
# 158  Computational follow-ups as part of Project 2.
# 159  Computational follow-ups as part of Project 2.
# 160  Computational follow-ups as part of Project 2.
# 161  Computational follow-ups as part of Project 2.
# 162  Computational follow-ups as part of Project 2.
#
#                           design_reference_hits_SMILES
# 0    CS(=O)(=O)NCC(=O)N1CCCCC1.COC(=O)CNC(=O)c1cc(C...
# 1                          CS(=O)(=O)NCC(=O)N1CCCCC1.*
# 2                          CS(=O)(=O)NCC(=O)N1CCCCC1.*
# 3    CS(=O)(=O)NCC(=O)N1CCCCC1.COC(=O)CNC(=O)c1cc(C...
# 4                  CS(=O)(=O)NCC(=O)N1CCCCC1.Oc1ccccn1
# ..                                                 ...
# 158  Cc1csc(CN[C@H]2CCNC2=O)n1.COC(=O)CNC(=O)c1cc(C...
# 159                            NC(=O)c1ccc2c(c1)CCN2.*
# 160                        Cc1csc(CN[C@H]2CCNC2=O)n1.*
# 161  CS(=O)(=O)Nc1ccc(CN)cc1.Cc1ccc(F)cc1NC(=O)c1cc...
# 162  CS(=O)(=O)NCC(=O)N1CCCCC1.COC(=O)CNC(=O)c1cc(C...
#
# [163 rows x 11 columns]
